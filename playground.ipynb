# %%
res = PcibexFarm('results 19.37.52.csv')

res.fit(stdise=True, wrong_ips=True)
res.fillers()
res.test_items(('id', 'noid'))
# Out:
# <ipython-input-109-03b5c35a2de5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fillers['grammatical'] = fillers['label'].str[1]
# <ipython-input-109-03b5c35a2de5>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fillers['grammatical'] = fillers['grammatical'].map({self.ungram:0, self.gram:1})
# /Users/shikunova/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
