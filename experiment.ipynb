# %%
import pandas as pd
import csv

content = []
fieldnames = ['reception_time', 'ip', 'controller',
             'order', 'label', 'lsg', 'sentence', 'answer',
             'correct', 'time']

# %%
with open('results.csv', 'r') as f:
    rdr = csv.DictReader(filter(lambda row: row[0]!='#', f), fieldnames=fieldnames)
    for line in rdr:
        if line['label'].startswith('id'):
            content.append(line)

# %%
# 1. Results reception time.
# 2. MD5 hash of participant's IP address.
# 3. Controller name.
# 4. Order number of item.
# 5. Inner element number.
# 6. Label.
# 7. Latin Square Group.
# 8. Sentence (or sentence MD5).
# 8. Question (NULL if none)..
# 9. Answer.
# 10. Whether or not answer was correct (NULL if N/A).
# 11. Time taken to answer..

# %%
df = pd.DataFrame.from_dict(content)
df
# Out:
#      reception_time                                ip controller order  \
# 0        1636880892  f22bc56aad1bc122b31322a6a09ec2f6         12     0
# 1        1636880892  f22bc56aad1bc122b31322a6a09ec2f6         12     0
# 2        1636880892  f22bc56aad1bc122b31322a6a09ec2f6         18     0
# 3        1636880892  f22bc56aad1bc122b31322a6a09ec2f6         18     0
# 4        1636880892  f22bc56aad1bc122b31322a6a09ec2f6          7     0
# ...             ...                               ...        ...   ...
# 1317     1637320461  50e8489de504ee406f46efe0ba6015e9         21     0
# 1318     1637320461  50e8489de504ee406f46efe0ba6015e9         10     0
# 1319     1637320461  50e8489de504ee406f46efe0ba6015e9         10     0
# 1320     1637320461  50e8489de504ee406f46efe0ba6015e9         17     0
# 1321     1637320461  50e8489de504ee406f46efe0ba6015e9         17     0
#
#                label lsg                                           sentence  \
# 0     id.mesh.pass.a   2  Хорошее воспитание не мешало грехам водиться з...
# 1     id.mesh.pass.a   2                                               NULL
# 2      id.pomo.act.a   4  Следователи были в полном замешательстве%2C но...
# 3      id.pomo.act.a   4                                               NULL
# 4      id.zast.act.b   1  Напряженное молчание заставляло атмосферу сгущ...
# ...              ...  ..                                                ...
# 1317   id.pomo.act.b   7                                               NULL
# 1318  id.zast.pass.a   2  Приход в администрацию нового руководства заст...
# 1319  id.zast.pass.a   2                                               NULL
# 1320   id.pozv.act.b   5  В команде проекта собрались отличные компетент...
# 1321   id.pozv.act.b   5                                               NULL
#
#      answer correct  time
# 0      None    None  None
# 1         4    NULL   411
# 2      None    None  None
# 3         4    NULL   408
# 4      None    None  None
# ...     ...     ...   ...
# 1317      7    NULL  9555
# 1318   None    None  None
# 1319      7    NULL  5174
# 1320   None    None  None
# 1321      7    NULL  9108
#
# [1322 rows x 10 columns]

# %%
label2sent = {ele['label']:ele['sentence'] for ele in content[::2]}

label2sent
# Out:
# {'id.mesh.pass.a': 'Хорошее воспитание не мешало грехам водиться за Аркашей. ',
#  'id.pomo.act.a': 'Следователи были в полном замешательстве%2C но рассказ очевидца помог всему встать на свои места. ',
#  'id.zast.act.b': 'Напряженное молчание заставляло атмосферу сгущаться сильнее и сильнее. ',
#  'id.pozv.pass.b': 'Школьная директриса Лариса Эдуардовна была сторонницей индивидуального подхода к ученикам и не позволяла ярлыкам вешаться без разбора. ',
#  'id.mesh.pass.b': 'Родительский контроль должен мешать головам детей забиваться чушью%2C которую они могут увидеть в интернете.',
#  'id.zast.pass.a': 'Приход в администрацию нового руководства заставил декорации смениться.',
#  'id.pomo.act.b': 'Алёна была в ярости%2C когда узнала%2C где муж побывал той ночью%2C но искренние извинения и пышный букет пионов помогли гневу смениться на милость.',
#  'id.pozv.act.a': 'Бесконечные промедления никак не позволяли делу сдвинуться с мёртвой точки.',
#  'id.zast.pass.b': 'Хватит учить Пашу писать стихи – заставляешь бумагу мараться почем зря.',
#  'id.pozv.act.b': 'В команде проекта собрались отличные компетентные люди%2C но отсутствие чётких указаний от руководителя всё никак не позволяло льду тронуться.',
#  'id.pomo.pass.a': 'Новые запретительные меры помогли гайкам закрутиться ещё сильнее. ',
#  'id.mesh.act.a': 'Мой день рождения проходил отлично%2C однако праздник не мешал кошкам скрести на душе. ',
#  'id.mesh.act.b': 'Никакие утешения не мешали слезам литься в три ручья – потерялась Анина любимая плюшевая собачка.',
#  'id.pozv.pass.a': 'Серёжка думал%2C поселить ли у себя в комнате домашнюю жабу%2C но внезапное появление отца позволило её судьбе решиться мгновенно – она была выдворена на улицу.',
#  'id.pomo.pass.b': 'Дружелюбный настрой Костиных новых знакомых и бутылка хорошего полусухого вина помогли льду растопиться быстро и легко.',
#  'id.zast.act.a': 'Очередной провал заставил почву уйти из-под ног молодого предпринимателя – выхода из ситуации не было никакого. '}

# %%
import numpy as np

df["answer"] = pd.to_numeric(df["answer"], downcast="float")
table = pd.pivot_table(df, values='answer', columns=['label'], aggfunc=np.nanmean)
table
# Out:
# label   id.mesh.act.a  id.mesh.act.b  id.mesh.pass.a  id.mesh.pass.b  \
# answer       4.404762       5.465117        3.636364        4.390244
#
# label   id.pomo.act.a  id.pomo.act.b  id.pomo.pass.a  id.pomo.pass.b  \
# answer       5.682927       5.772727        3.954545             4.5
#
# label   id.pozv.act.a  id.pozv.act.b  id.pozv.pass.a  id.pozv.pass.b  \
# answer       6.170732       5.659091        5.209302         4.04878
#
# label   id.zast.act.a  id.zast.act.b  id.zast.pass.a  id.zast.pass.b
# answer            5.3       5.022727        4.636364        3.463415

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

colors = ['grey', 'pink', 'brown', 'purple']
plt.xticks(rotation=90)

words = ['mesh', 'pomo', 'pozv', 'zast']
for key in table.to_dict().keys():
    plt.bar(key, round(table.to_dict()[key]['answer'], 3), color=colors[words.index(key.split('.')[1])])

plt.title('Стимулы')
plt.ylabel('Оценка')
plt.xlabel('Пример')
plt.show()

for key in table.to_dict().keys():
    print(f'{key}\t\t{label2sent[key]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-270604eecd9e> in <module>
#       6
#       7 words = ['mesh', 'pomo', 'pozv', 'zast']
# ----> 8 for key in table.to_dict().keys():
#       9     plt.bar(key, round(table.to_dict()[key]['answer'], 3), color=colors[words.index(key.split('.')[1])])
#      10
#
# NameError: name 'table' is not defined

# %%
df['ip'].nunique()
# Out:
# 80

# %%
from scipy import stats

X = list(df['label'].unique())
Y = []
for l in [list(df.loc[df['label'] == label]['answer'])[1::2] for label in df['label'].unique()]:
    Y.append(stats.ttest_1samp(l,5.0)[1])
    
pvalues = dict(sorted(zip(X, Y)))
X = list(pvalues.keys())
Y = list(pvalues.values())

plt.xticks(rotation=90)
plt.yscale('log')

plt.axhline(y=0.001, color='green')
plt.axhline(y=0.01, color='yellow')
plt.axhline(y=0.05, color='orange')
plt.axhline(y=0.1, color='red')

#plt.bar(X, Y, color='grey')
for key in pvalues:
    plt.bar(key, pvalues[key], color=colors[words.index(key.split('.')[1])])

plt.title('P-values')
plt.ylabel('p')
plt.xlabel('')
plt.show()

for i in range(len(Y)):
    print(f'{X[i]}\t\t{round(Y[i], 5)}')
# Out:
# id.mesh.act.a		0.02465
# id.mesh.act.b		0.06962
# id.mesh.pass.a		9e-05
# id.mesh.pass.b		0.01016
# id.pomo.act.a		0.00763
# id.pomo.act.b		0.00043
# id.pomo.pass.a		0.00151
# id.pomo.pass.b		0.12884
# id.pozv.act.a		0.0
# id.pozv.act.b		0.01023
# id.pozv.pass.a		0.41577
# id.pozv.pass.b		0.00092
# id.zast.act.a		0.26203
# id.zast.act.b		0.93625
# id.zast.pass.a		0.19775
# id.zast.pass.b		1e-05

# %%
ttest = {}

for label in pvalues:
    if pvalues[label] <= 10**(-3):
        ttest[label] = 'GOOD'
    elif 10**(-3) <= pvalues[label] <= 10**(-2):
        ttest[label] = 'moderate'
    elif 10**(-2) <= pvalues[label] <= 10**(-2)*5:
        ttest[label] = 'weak'
    elif 10**(-2)*5 <= pvalues[label] <= 10**(-1):
        ttest[label] = 'very weak'
    else:
        ttest[label] = 'no evidence :('
    

for i in range(len(X)):
    print(f'{X[i]}\t{round(float(table[X[i]]), 2)}\t{ttest[X[i]]}')
    if i%4 == 3:
        print('\n')
        
label2sent
# Out:
# id.mesh.act.a	4.4	weak
# id.mesh.act.b	5.47	very weak
# id.mesh.pass.a	3.64	GOOD
# id.mesh.pass.b	4.39	weak
#
#
# id.pomo.act.a	5.68	moderate
# id.pomo.act.b	5.77	GOOD
# id.pomo.pass.a	3.95	moderate
# id.pomo.pass.b	4.5	no evidence :(
#
#
# id.pozv.act.a	6.17	GOOD
# id.pozv.act.b	5.66	weak
# id.pozv.pass.a	5.21	no evidence :(
# id.pozv.pass.b	4.05	GOOD
#
#
# id.zast.act.a	5.3	no evidence :(
# id.zast.act.b	5.02	no evidence :(
# id.zast.pass.a	4.64	no evidence :(
# id.zast.pass.b	3.46	GOOD
# {'id.mesh.act.a': 'Мой день рождения проходил отлично%2C однако праздник не мешал кошкам скрести на душе. ',
#  'id.pomo.pass.b': 'Дружелюбный настрой Костиных новых знакомых и бутылка хорошего полусухого вина помогли льду растопиться быстро и легко.',
#  'id.mesh.pass.b': 'Родительский контроль должен мешать головам детей забиваться чушью%2C которую они могут увидеть в интернете.',
#  'id.pozv.pass.b': 'Школьная директриса Лариса Эдуардовна была сторонницей индивидуального подхода к ученикам и не позволяла ярлыкам вешаться без разбора. ',
#  'id.pozv.act.a': 'Бесконечные промедления никак не позволяли делу сдвинуться с мёртвой точки.',
#  'id.pomo.act.a': 'Следователи были в полном замешательстве%2C но рассказ очевидца помог всему встать на свои места. ',
#  'id.zast.act.a': 'Очередной провал заставил почву уйти из-под ног молодого предпринимателя – выхода из ситуации не было никакого. ',
#  'id.zast.pass.b': 'Хватит учить Пашу писать стихи – заставляешь бумагу мараться почем зря.',
#  'id.mesh.act.b': 'Никакие утешения не мешали слезам литься в три ручья – потерялась Анина любимая плюшевая собачка.',
#  'id.zast.act.b': 'Напряженное молчание заставляло атмосферу сгущаться сильнее и сильнее. ',
#  'id.mesh.pass.a': 'Хорошее воспитание не мешало грехам водиться за Аркашей. ',
#  'id.pozv.pass.a': 'Серёжка думал%2C поселить ли у себя в комнате домашнюю жабу%2C но внезапное появление отца позволило её судьбе решиться мгновенно – она была выдворена на улицу.',
#  'id.pomo.pass.a': 'Новые запретительные меры помогли гайкам закрутиться ещё сильнее. ',
#  'id.pomo.act.b': 'Алёна была в ярости%2C когда узнала%2C где муж побывал той ночью%2C но искренние извинения и пышный букет пионов помогли гневу смениться на милость.',
#  'id.zast.pass.a': 'Приход в администрацию нового руководства заставил декорации смениться.',
#  'id.pozv.act.b': 'В команде проекта собрались отличные компетентные люди%2C но отсутствие чётких указаний от руководителя всё никак не позволяло льду тронуться.'}

# %%
fillers = []

# %%
with open('results 13.41.50.csv', 'r') as f:
    rdr = csv.DictReader(filter(lambda row: row[0]!='#', f), fieldnames=fieldnames)
    for line in rdr:
        if line['label'].startswith('F'):
            fillers.append(line)

# %%
ff = pd.DataFrame.from_dict(fillers)
ff["answer"] = pd.to_numeric(ff["answer"], downcast="float")

# %%
from scipy import stats
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)

pvalues = []
for l in [list(ff.loc[ff['label'] == label]['answer'])[1::2] for label in ff['label'].unique()]:
    pvalues.append((stats.ttest_1samp(l,5.0)[1]))
    
Y = sorted(pvalues)
X = list(ff['label'].unique())
plt.xticks(rotation=90)
plt.yscale('log')

plt.axhline(y=0.001, color='green')
plt.axhline(y=0.01, color='yellow')
plt.axhline(y=0.05, color='orange')
plt.axhline(y=0.1, color='red')

plt.bar(X, Y, color='grey')
plt.title('')
plt.ylabel('')
plt.xlabel('')
plt.show()

for i in range(len(Y)):
    print(f'{X[i]}\t\t{round(Y[i], 5)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5e333d7c3c8f> in <module>
#      10 Y = sorted(pvalues)
#      11 X = list(ff['label'].unique())
# ---> 12 plt.xticks(rotation=90)
#      13 plt.yscale('log')
#      14
#
# NameError: name 'plt' is not defined

# %%
Y = sorted(list(df.loc[df['label'] == 'id.mesh.act.b']['answer'])[1::2])
X = [i for i in range(len(Y))]

plt.bar(X, Y, color='green')
plt.title('')
plt.ylabel('')
plt.xlabel('')
plt.show()

# %%
df
# Out:
#      reception_time                                ip controller order  \
# 0        1637172021  9fec503f35981a6ebc1af94b25381660         12     0
# 1        1637172021  9fec503f35981a6ebc1af94b25381660         12     0
# 2        1637172021  9fec503f35981a6ebc1af94b25381660         23     0
# 3        1637172021  9fec503f35981a6ebc1af94b25381660         23     0
# 4        1637172021  9fec503f35981a6ebc1af94b25381660         15     0
# ...             ...                               ...        ...   ...
# 1349     1637172021  9fec503f35981a6ebc1af94b25381660         20     0
# 1350     1637172021  9fec503f35981a6ebc1af94b25381660          8     0
# 1351     1637172021  9fec503f35981a6ebc1af94b25381660          8     0
# 1352     1637172021  9fec503f35981a6ebc1af94b25381660         11     0
# 1353     1637172021  9fec503f35981a6ebc1af94b25381660         11     0
#
#                label lsg                                           sentence  \
# 0      id.mesh.act.a   3  Мой день рождения проходил отлично%2C однако п...
# 1      id.mesh.act.a   3                                               NULL
# 2     id.pomo.pass.b   8  Дружелюбный настрой Костиных новых знакомых и ...
# 3     id.pomo.pass.b   8                                               NULL
# 4     id.mesh.pass.b   4  Родительский контроль должен мешать головам де...
# ...              ...  ..                                                ...
# 1349   id.pomo.act.a   7                                               NULL
# 1350   id.zast.act.a   1  Очередной провал заставил почву уйти из-под но...
# 1351   id.zast.act.a   1                                               NULL
# 1352  id.zast.pass.b   2  Хватит учить Пашу писать стихи – заставляешь б...
# 1353  id.zast.pass.b   2                                               NULL
#
#      answer correct  time
# 0      None    None  None
# 1         2    NULL  4021
# 2      None    None  None
# 3         7    NULL  6975
# 4      None    None  None
# ...     ...     ...   ...
# 1349      7    NULL  4831
# 1350   None    None  None
# 1351      7    NULL  4488
# 1352   None    None  None
# 1353      1    NULL  3272
#
# [1354 rows x 10 columns]

# %%
df = pd.DataFrame.from_dict(content)

norm = []
keys = ['reception_time', 'ip', 'label', 'sentence', 'answer', 'time']

# %%
for line in list(content)[::2]:
    dic = {}
    for key in keys:
        if line[key] and line[key] != 'NULL':
            dic[key] = line[key]
    norm.append(dic)
    
print(len(norm))
        
for line in list(content)[1::2]:
    for key in keys:
        if line[key] and line[key] != 'NULL':
            norm[list(content).index(line)//2][key] = line[key]
            
print(len(norm))
# Out:
# 661
# 661

# %%
with open('results_normal.csv', 'w') as f:
    writer = csv.DictWriter(f, fieldnames=keys)
    writer.writeheader()
    for line in norm:
        writer.writerow(line)

# %%
fillers
# Out:
# [{'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '38',
#   'order': '0',
#   'label': 'Fu-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'Анечка совсем не хотела есть суп%2C потому что терпеть не могло вареный луком. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '38',
#   'order': '0',
#   'label': 'Fu-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '2672'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '22',
#   'order': '0',
#   'label': 'Fg-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'Если бы не дождь с градом%2C я бы пошла сегодня гулять в Петровский парк. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '22',
#   'order': '0',
#   'label': 'Fg-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '820'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '42',
#   'order': '0',
#   'label': 'Fu-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'Дома холодные полы%2C поэтому бабушка настаивает%2C чтобы гости наденут тапочки. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '42',
#   'order': '0',
#   'label': 'Fu-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '599'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '27',
#   'order': '0',
#   'label': 'Fg-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'Курины уехали на дачу на две недели%2C и до них теперь не дозвонишься.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '27',
#   'order': '0',
#   'label': 'Fg-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '462'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '44',
#   'order': '0',
#   'label': 'Fu-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'Дедлайн стремительно приближался%2C а я успевает сделать примерно ничего. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '44',
#   'order': '0',
#   'label': 'Fu-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '557'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '32',
#   'order': '0',
#   'label': 'Fg-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'Никто не заставляет Витю просыпаться в шесть утра%2C он сам поднимается и идет на пробежку. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '32',
#   'order': '0',
#   'label': 'Fg-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '514'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '52',
#   'order': '0',
#   'label': 'Fu-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'Нике явно не нравилось вечеринке%2C у неё болела голова и она поскорее хотела пойдёт домой.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '52',
#   'order': '0',
#   'label': 'Fu-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '461'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '23',
#   'order': '0',
#   'label': 'Fg-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'Меня пригласили на выставку%2C посвященную русским супрематистам%2C но мне совсем не хотелось идти. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '23',
#   'order': '0',
#   'label': 'Fg-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '410'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '39',
#   'order': '0',
#   'label': 'Fu-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'Все были взволнованы после ухода Петра Степановича%2C даже Лизе. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '39',
#   'order': '0',
#   'label': 'Fu-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '459'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '30',
#   'order': '0',
#   'label': 'Fg-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'На поле рядом с моим домом уже давно ничего не выращивают. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '30',
#   'order': '0',
#   'label': 'Fg-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '485'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '41',
#   'order': '0',
#   'label': 'Fu-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'Если мой рассказ тебя не убедишь%2C поговори с Алисой – она отлично разбирается в людях. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '41',
#   'order': '0',
#   'label': 'Fu-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '436'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '24',
#   'order': '0',
#   'label': 'Fg-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'Алёше уже не нужны костыли – его нога совсем зажила. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '24',
#   'order': '0',
#   'label': 'Fg-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '425'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '51',
#   'order': '0',
#   'label': 'Fu-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'Дойдя до вертолётной площадки%2C мы повернулись назад и увидели закат холодное осеннего солнце.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '51',
#   'order': '0',
#   'label': 'Fu-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '445'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '34',
#   'order': '0',
#   'label': 'Fg-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'Квартира в пригороде Москвы дешевле%2C но ежедневно добираться оттуда на работу – большая трата времени. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '34',
#   'order': '0',
#   'label': 'Fg-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '458'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '49',
#   'order': '0',
#   'label': 'Fu-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'Виктор опять не принес сочинение на урок литературы%2C и учитель снова начал за отчитывать его возмутительное неприлежание.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '49',
#   'order': '0',
#   'label': 'Fu-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '350'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '33',
#   'order': '0',
#   'label': 'Fg-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'Нет ничего красивее блестящих на солнце луж.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '33',
#   'order': '0',
#   'label': 'Fg-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '407'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '46',
#   'order': '0',
#   'label': 'Fu-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'Ты правда научился читать всего в три лет?',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '46',
#   'order': '0',
#   'label': 'Fu-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '464'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '25',
#   'order': '0',
#   'label': 'Fg-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'Сколько он ни пытался%2C не даётся ему сербский язык – то ли дело итальянский.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '25',
#   'order': '0',
#   'label': 'Fg-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '429'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '48',
#   'order': '0',
#   'label': 'Fu-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'На стене висел акварельные этюды%2C исчерканные углевым карандашом для придания глубины%2C карта Израиля и круглыми часы. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '48',
#   'order': '0',
#   'label': 'Fu-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '409'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '35',
#   'order': '0',
#   'label': 'Fg-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'Новосибирск оказался вовсе не таким%2C каким Лиза его себе представляла.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '35',
#   'order': '0',
#   'label': 'Fg-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '331'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '47',
#   'order': '0',
#   'label': 'Fu-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'Рыбу здесь запрещено ловил сетями и пугал бы взрывчаткой.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '47',
#   'order': '0',
#   'label': 'Fu-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '385'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '28',
#   'order': '0',
#   'label': 'Fg-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'Химия так плохо давалась Насте%2C что пришлось нанять репетитора – студента 4 курса МГУ. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '28',
#   'order': '0',
#   'label': 'Fg-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '314'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '40',
#   'order': '0',
#   'label': 'Fu-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'У меня никогда не было музыкальных способностей%2C но я отличалась склонностью рисованием. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '40',
#   'order': '0',
#   'label': 'Fu-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '445'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '36',
#   'order': '0',
#   'label': 'Fg-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'Папа купил лимонад и килограмм креветок – вечером будет маленькое застолье.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '36',
#   'order': '0',
#   'label': 'Fg-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '482'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '43',
#   'order': '0',
#   'label': 'Fu-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'Больше всего маленький Ваня боялся темноты%2C и поэтому света засыпал без никогда. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '43',
#   'order': '0',
#   'label': 'Fu-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '482'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '37',
#   'order': '0',
#   'label': 'Fg-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'Каждый раз%2C когда я прохожу мимо памятника Ленину%2C мне кажется%2C что он шатается.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '37',
#   'order': '0',
#   'label': 'Fg-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '470'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '50',
#   'order': '0',
#   'label': 'Fu-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'Со второго ряда уже было лектора плохо слышный%2C а до задних парт доходило еле-еле.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '50',
#   'order': '0',
#   'label': 'Fu-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '449'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'Девчонки столпились у окна%2C чтобы посмотреть на двойную радугу%2C но никак не могли её разглядеть.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '432'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '53',
#   'order': '0',
#   'label': 'Fu-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'Как настоящая творческая личность%2C Никитка скоро украсил обои в прихожей при помощью своих новых фломастерами.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '53',
#   'order': '0',
#   'label': 'Fu-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '435'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '29',
#   'order': '0',
#   'label': 'Fg-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'Римма боится собак%2C да так%2C что может в обморок упасть%2C если Рекс на неё зарычит.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '29',
#   'order': '0',
#   'label': 'Fg-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '350'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '45',
#   'order': '0',
#   'label': 'Fu-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'Один наушник нашлись в углу прихожей%2C а другой – под тумбочке. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '45',
#   'order': '0',
#   'label': 'Fu-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '368'},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '26',
#   'order': '0',
#   'label': 'Fg-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'Мама надела сапоги%2C чёрное пальто%2C накинула на голову подаренный отцом шелковый платок и вышла во двор. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636880892',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '26',
#   'order': '0',
#   'label': 'Fg-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '486'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '39',
#   'order': '0',
#   'label': 'Fu-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'Все были взволнованы после ухода Петра Степановича%2C даже Лизе. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '39',
#   'order': '0',
#   'label': 'Fu-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '2403'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '22',
#   'order': '0',
#   'label': 'Fg-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'Если бы не дождь с градом%2C я бы пошла сегодня гулять в Петровский парк. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '22',
#   'order': '0',
#   'label': 'Fg-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '482'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '53',
#   'order': '0',
#   'label': 'Fu-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'Как настоящая творческая личность%2C Никитка скоро украсил обои в прихожей при помощью своих новых фломастерами.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '53',
#   'order': '0',
#   'label': 'Fu-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '484'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '36',
#   'order': '0',
#   'label': 'Fg-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'Папа купил лимонад и килограмм креветок – вечером будет маленькое застолье.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '36',
#   'order': '0',
#   'label': 'Fg-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '423'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '52',
#   'order': '0',
#   'label': 'Fu-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'Нике явно не нравилось вечеринке%2C у неё болела голова и она поскорее хотела пойдёт домой.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '52',
#   'order': '0',
#   'label': 'Fu-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '852'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '35',
#   'order': '0',
#   'label': 'Fg-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'Новосибирск оказался вовсе не таким%2C каким Лиза его себе представляла.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '35',
#   'order': '0',
#   'label': 'Fg-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '465'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '43',
#   'order': '0',
#   'label': 'Fu-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'Больше всего маленький Ваня боялся темноты%2C и поэтому света засыпал без никогда. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '43',
#   'order': '0',
#   'label': 'Fu-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '572'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '30',
#   'order': '0',
#   'label': 'Fg-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'На поле рядом с моим домом уже давно ничего не выращивают. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '30',
#   'order': '0',
#   'label': 'Fg-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '458'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '44',
#   'order': '0',
#   'label': 'Fu-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'Дедлайн стремительно приближался%2C а я успевает сделать примерно ничего. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '44',
#   'order': '0',
#   'label': 'Fu-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '516'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '29',
#   'order': '0',
#   'label': 'Fg-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'Римма боится собак%2C да так%2C что может в обморок упасть%2C если Рекс на неё зарычит.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '29',
#   'order': '0',
#   'label': 'Fg-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '508'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '42',
#   'order': '0',
#   'label': 'Fu-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'Дома холодные полы%2C поэтому бабушка настаивает%2C чтобы гости наденут тапочки. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '42',
#   'order': '0',
#   'label': 'Fu-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '475'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '24',
#   'order': '0',
#   'label': 'Fg-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'Алёше уже не нужны костыли – его нога совсем зажила. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '24',
#   'order': '0',
#   'label': 'Fg-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '402'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '45',
#   'order': '0',
#   'label': 'Fu-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'Один наушник нашлись в углу прихожей%2C а другой – под тумбочке. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '45',
#   'order': '0',
#   'label': 'Fu-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '471'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '26',
#   'order': '0',
#   'label': 'Fg-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'Мама надела сапоги%2C чёрное пальто%2C накинула на голову подаренный отцом шелковый платок и вышла во двор. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '26',
#   'order': '0',
#   'label': 'Fg-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '478'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '50',
#   'order': '0',
#   'label': 'Fu-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'Со второго ряда уже было лектора плохо слышный%2C а до задних парт доходило еле-еле.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '50',
#   'order': '0',
#   'label': 'Fu-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '466'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '23',
#   'order': '0',
#   'label': 'Fg-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'Меня пригласили на выставку%2C посвященную русским супрематистам%2C но мне совсем не хотелось идти. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '23',
#   'order': '0',
#   'label': 'Fg-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '455'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '47',
#   'order': '0',
#   'label': 'Fu-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'Рыбу здесь запрещено ловил сетями и пугал бы взрывчаткой.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '47',
#   'order': '0',
#   'label': 'Fu-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '452'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '28',
#   'order': '0',
#   'label': 'Fg-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'Химия так плохо давалась Насте%2C что пришлось нанять репетитора – студента 4 курса МГУ. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '28',
#   'order': '0',
#   'label': 'Fg-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '501'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '38',
#   'order': '0',
#   'label': 'Fu-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'Анечка совсем не хотела есть суп%2C потому что терпеть не могло вареный луком. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '38',
#   'order': '0',
#   'label': 'Fu-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '515'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '37',
#   'order': '0',
#   'label': 'Fg-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'Каждый раз%2C когда я прохожу мимо памятника Ленину%2C мне кажется%2C что он шатается.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '37',
#   'order': '0',
#   'label': 'Fg-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '433'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '40',
#   'order': '0',
#   'label': 'Fu-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'У меня никогда не было музыкальных способностей%2C но я отличалась склонностью рисованием. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '40',
#   'order': '0',
#   'label': 'Fu-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '396'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '25',
#   'order': '0',
#   'label': 'Fg-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'Сколько он ни пытался%2C не даётся ему сербский язык – то ли дело итальянский.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '25',
#   'order': '0',
#   'label': 'Fg-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '436'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '46',
#   'order': '0',
#   'label': 'Fu-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'Ты правда научился читать всего в три лет?',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '46',
#   'order': '0',
#   'label': 'Fu-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '414'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'Девчонки столпились у окна%2C чтобы посмотреть на двойную радугу%2C но никак не могли её разглядеть.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '406'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '49',
#   'order': '0',
#   'label': 'Fu-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'Виктор опять не принес сочинение на урок литературы%2C и учитель снова начал за отчитывать его возмутительное неприлежание.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '49',
#   'order': '0',
#   'label': 'Fu-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '424'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '27',
#   'order': '0',
#   'label': 'Fg-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'Курины уехали на дачу на две недели%2C и до них теперь не дозвонишься.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '27',
#   'order': '0',
#   'label': 'Fg-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '414'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '51',
#   'order': '0',
#   'label': 'Fu-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'Дойдя до вертолётной площадки%2C мы повернулись назад и увидели закат холодное осеннего солнце.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '51',
#   'order': '0',
#   'label': 'Fu-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '390'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '33',
#   'order': '0',
#   'label': 'Fg-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'Нет ничего красивее блестящих на солнце луж.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '33',
#   'order': '0',
#   'label': 'Fg-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '409'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '41',
#   'order': '0',
#   'label': 'Fu-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'Если мой рассказ тебя не убедишь%2C поговори с Алисой – она отлично разбирается в людях. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '41',
#   'order': '0',
#   'label': 'Fu-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '393'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '32',
#   'order': '0',
#   'label': 'Fg-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'Никто не заставляет Витю просыпаться в шесть утра%2C он сам поднимается и идет на пробежку. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '32',
#   'order': '0',
#   'label': 'Fg-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '376'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '48',
#   'order': '0',
#   'label': 'Fu-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'На стене висел акварельные этюды%2C исчерканные углевым карандашом для придания глубины%2C карта Израиля и круглыми часы. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '48',
#   'order': '0',
#   'label': 'Fu-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '413'},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '34',
#   'order': '0',
#   'label': 'Fg-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'Квартира в пригороде Москвы дешевле%2C но ежедневно добираться оттуда на работу – большая трата времени. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881140',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '34',
#   'order': '0',
#   'label': 'Fg-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '403'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'Девчонки столпились у окна%2C чтобы посмотреть на двойную радугу%2C но никак не могли её разглядеть.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-5F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '2392'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '43',
#   'order': '0',
#   'label': 'Fu-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'Больше всего маленький Ваня боялся темноты%2C и поэтому света засыпал без никогда. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '43',
#   'order': '0',
#   'label': 'Fu-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '512'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '27',
#   'order': '0',
#   'label': 'Fg-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'Курины уехали на дачу на две недели%2C и до них теперь не дозвонишься.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '27',
#   'order': '0',
#   'label': 'Fg-3F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '456'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '39',
#   'order': '0',
#   'label': 'Fu-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'Все были взволнованы после ухода Петра Степановича%2C даже Лизе. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '39',
#   'order': '0',
#   'label': 'Fu-1F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '494'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '30',
#   'order': '0',
#   'label': 'Fg-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'На поле рядом с моим домом уже давно ничего не выращивают. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '30',
#   'order': '0',
#   'label': 'Fg-5F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '467'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '44',
#   'order': '0',
#   'label': 'Fu-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'Дедлайн стремительно приближался%2C а я успевает сделать примерно ничего. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '44',
#   'order': '0',
#   'label': 'Fu-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '668'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '26',
#   'order': '0',
#   'label': 'Fg-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'Мама надела сапоги%2C чёрное пальто%2C накинула на голову подаренный отцом шелковый платок и вышла во двор. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '26',
#   'order': '0',
#   'label': 'Fg-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '476'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '38',
#   'order': '0',
#   'label': 'Fu-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'Анечка совсем не хотела есть суп%2C потому что терпеть не могло вареный луком. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '38',
#   'order': '0',
#   'label': 'Fu-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '550'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '24',
#   'order': '0',
#   'label': 'Fg-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'Алёше уже не нужны костыли – его нога совсем зажила. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '24',
#   'order': '0',
#   'label': 'Fg-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '507'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '41',
#   'order': '0',
#   'label': 'Fu-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'Если мой рассказ тебя не убедишь%2C поговори с Алисой – она отлично разбирается в людях. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '41',
#   'order': '0',
#   'label': 'Fu-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '478'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '22',
#   'order': '0',
#   'label': 'Fg-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'Если бы не дождь с градом%2C я бы пошла сегодня гулять в Петровский парк. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '22',
#   'order': '0',
#   'label': 'Fg-1F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '471'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '51',
#   'order': '0',
#   'label': 'Fu-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'Дойдя до вертолётной площадки%2C мы повернулись назад и увидели закат холодное осеннего солнце.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '51',
#   'order': '0',
#   'label': 'Fu-7F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '546'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '33',
#   'order': '0',
#   'label': 'Fg-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'Нет ничего красивее блестящих на солнце луж.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '33',
#   'order': '0',
#   'label': 'Fg-6F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '530'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '40',
#   'order': '0',
#   'label': 'Fu-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'У меня никогда не было музыкальных способностей%2C но я отличалась склонностью рисованием. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '40',
#   'order': '0',
#   'label': 'Fu-2F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '499'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '25',
#   'order': '0',
#   'label': 'Fg-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'Сколько он ни пытался%2C не даётся ему сербский язык – то ли дело итальянский.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '25',
#   'order': '0',
#   'label': 'Fg-2F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '488'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '48',
#   'order': '0',
#   'label': 'Fu-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'На стене висел акварельные этюды%2C исчерканные углевым карандашом для придания глубины%2C карта Израиля и круглыми часы. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '48',
#   'order': '0',
#   'label': 'Fu-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '495'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '28',
#   'order': '0',
#   'label': 'Fg-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'Химия так плохо давалась Насте%2C что пришлось нанять репетитора – студента 4 курса МГУ. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '28',
#   'order': '0',
#   'label': 'Fg-4F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '532'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '42',
#   'order': '0',
#   'label': 'Fu-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'Дома холодные полы%2C поэтому бабушка настаивает%2C чтобы гости наденут тапочки. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '42',
#   'order': '0',
#   'label': 'Fu-3F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '488'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '32',
#   'order': '0',
#   'label': 'Fg-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'Никто не заставляет Витю просыпаться в шесть утра%2C он сам поднимается и идет на пробежку. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '32',
#   'order': '0',
#   'label': 'Fg-6F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '540'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '53',
#   'order': '0',
#   'label': 'Fu-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'Как настоящая творческая личность%2C Никитка скоро украсил обои в прихожей при помощью своих новых фломастерами.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '53',
#   'order': '0',
#   'label': 'Fu-8F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '464'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '36',
#   'order': '0',
#   'label': 'Fg-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'Папа купил лимонад и килограмм креветок – вечером будет маленькое застолье.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '36',
#   'order': '0',
#   'label': 'Fg-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '500'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '52',
#   'order': '0',
#   'label': 'Fu-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'Нике явно не нравилось вечеринке%2C у неё болела голова и она поскорее хотела пойдёт домой.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '52',
#   'order': '0',
#   'label': 'Fu-8F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '480'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '34',
#   'order': '0',
#   'label': 'Fg-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'Квартира в пригороде Москвы дешевле%2C но ежедневно добираться оттуда на работу – большая трата времени. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '34',
#   'order': '0',
#   'label': 'Fg-7F.01',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '452'},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '45',
#   'order': '0',
#   'label': 'Fu-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'Один наушник нашлись в углу прихожей%2C а другой – под тумбочке. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1636881210',
#   'ip': 'f22bc56aad1bc122b31322a6a09ec2f6',
#   'controller': '45',
#   'order': '0',
#   'label': 'Fu-4F.02',
#   'lsg': 'NULL',
#   'sentence': 'NULL',
#   'answer': '5',
#   'correct': 'NULL',
#   'time': '487'},
#  {'reception_time': '1636881210',
# ...
#  {'reception_time': '1636907044',
#   'ip': 'eb4c6ea5499ac8db6032c2edbdae4adf',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-4F.02',
#   'lsg': '12',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '13207'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '52',
#   'order': '0',
#   'label': 'Fu-7F.01',
#   'lsg': '23',
#   'sentence': 'Со второго ряда уже было лектора плохо слышный%2C а до задних парт доходило еле-еле.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '52',
#   'order': '0',
#   'label': 'Fu-7F.01',
#   'lsg': '23',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '2207'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '28',
#   'order': '0',
#   'label': 'Fg-3F.01',
#   'lsg': '11',
#   'sentence': 'Мама надела сапоги%2C чёрное пальто%2C накинула на голову подаренный отцом шелковый платок и вышла во двор. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '28',
#   'order': '0',
#   'label': 'Fg-3F.01',
#   'lsg': '11',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '3628'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '44',
#   'order': '0',
#   'label': 'Fu-3F.01',
#   'lsg': '19',
#   'sentence': 'Дома холодные полы%2C поэтому бабушка настаивает%2C чтобы гости наденут тапочки. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '44',
#   'order': '0',
#   'label': 'Fu-3F.01',
#   'lsg': '19',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '4493'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '24',
#   'order': '0',
#   'label': 'Fg-1F.01',
#   'lsg': '9',
#   'sentence': 'Если бы не дождь с градом%2C я бы пошла сегодня гулять в Петровский парк. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '24',
#   'order': '0',
#   'label': 'Fg-1F.01',
#   'lsg': '9',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '4493'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '55',
#   'order': '0',
#   'label': 'Fu-8F.02',
#   'lsg': '24',
#   'sentence': 'Как настоящая творческая личность%2C Никитка скоро украсил обои в прихожей при помощью своих новых фломастерами.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '55',
#   'order': '0',
#   'label': 'Fu-8F.02',
#   'lsg': '24',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '4939'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '27',
#   'order': '0',
#   'label': 'Fg-2F.02',
#   'lsg': '10',
#   'sentence': 'Сколько он ни пытался%2C не даётся ему сербский язык – то ли дело итальянский.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '27',
#   'order': '0',
#   'label': 'Fg-2F.02',
#   'lsg': '10',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '3924'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '43',
#   'order': '0',
#   'label': 'Fu-2F.02',
#   'lsg': '18',
#   'sentence': 'Если мой рассказ тебя не убедишь%2C поговори с Алисой – она отлично разбирается в людях. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '43',
#   'order': '0',
#   'label': 'Fu-2F.02',
#   'lsg': '18',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '1812'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '39',
#   'order': '0',
#   'label': 'Fg-8F.02',
#   'lsg': '16',
#   'sentence': 'Каждый раз%2C когда я прохожу мимо памятника Ленину%2C мне кажется%2C что он шатается.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '39',
#   'order': '0',
#   'label': 'Fg-8F.02',
#   'lsg': '16',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '4239'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '40',
#   'order': '0',
#   'label': 'Fu-1F.01',
#   'lsg': '17',
#   'sentence': 'Анечка совсем не хотела есть суп%2C потому что терпеть не могло вареный луком. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '40',
#   'order': '0',
#   'label': 'Fu-1F.01',
#   'lsg': '17',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '2093'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '36',
#   'order': '0',
#   'label': 'Fg-7F.01',
#   'lsg': '15',
#   'sentence': 'Квартира в пригороде Москвы дешевле%2C но ежедневно добираться оттуда на работу – большая трата времени. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '36',
#   'order': '0',
#   'label': 'Fg-7F.01',
#   'lsg': '15',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '3185'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '48',
#   'order': '0',
#   'label': 'Fu-5F.01',
#   'lsg': '21',
#   'sentence': 'Ты правда научился читать всего в три лет?',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '48',
#   'order': '0',
#   'label': 'Fu-5F.01',
#   'lsg': '21',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '2720'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-4F.02',
#   'lsg': '12',
#   'sentence': 'Римма боится собак%2C да так%2C что может в обморок упасть%2C если Рекс на неё зарычит.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '31',
#   'order': '0',
#   'label': 'Fg-4F.02',
#   'lsg': '12',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '4237'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '51',
#   'order': '0',
#   'label': 'Fu-6F.02',
#   'lsg': '22',
#   'sentence': 'Виктор опять не принес сочинение на урок литературы%2C и учитель снова начал за отчитывать его возмутительное неприлежание.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '51',
#   'order': '0',
#   'label': 'Fu-6F.02',
#   'lsg': '22',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '7454'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '35',
#   'order': '0',
#   'label': 'Fg-6F.02',
#   'lsg': '14',
#   'sentence': 'Нет ничего красивее блестящих на солнце луж.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '35',
#   'order': '0',
#   'label': 'Fg-6F.02',
#   'lsg': '14',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '1581'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '47',
#   'order': '0',
#   'label': 'Fu-4F.02',
#   'lsg': '20',
#   'sentence': 'Один наушник нашлись в углу прихожей%2C а другой – под тумбочке. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '47',
#   'order': '0',
#   'label': 'Fu-4F.02',
#   'lsg': '20',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '1520'},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '32',
#   'order': '0',
#   'label': 'Fg-5F.01',
#   'lsg': '13',
#   'sentence': 'На поле рядом с моим домом уже давно ничего не выращивают. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637004410',
#   'ip': 'cda49bb0b14f2e0790c138a2d39a1367',
#   'controller': '32',
#   'order': '0',
#   'label': 'Fg-5F.01',
#   'lsg': '13',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '5070'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '50',
#   'order': '0',
#   'label': 'Fu-6F.01',
#   'lsg': '22',
#   'sentence': 'На стене висел акварельные этюды%2C исчерканные углевым карандашом для придания глубины%2C карта Израиля и круглыми часы. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '50',
#   'order': '0',
#   'label': 'Fu-6F.01',
#   'lsg': '22',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '9791'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '25',
#   'order': '0',
#   'label': 'Fg-1F.02',
#   'lsg': '9',
#   'sentence': 'Меня пригласили на выставку%2C посвященную русским супрематистам%2C но мне совсем не хотелось идти. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '25',
#   'order': '0',
#   'label': 'Fg-1F.02',
#   'lsg': '9',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '9235'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '41',
#   'order': '0',
#   'label': 'Fu-1F.02',
#   'lsg': '17',
#   'sentence': 'Все были взволнованы после ухода Петра Степановича%2C даже Лизе. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '41',
#   'order': '0',
#   'label': 'Fu-1F.02',
#   'lsg': '17',
#   'sentence': 'NULL',
#   'answer': '4',
#   'correct': 'NULL',
#   'time': '5459'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '38',
#   'order': '0',
#   'label': 'Fg-8F.01',
#   'lsg': '16',
#   'sentence': 'Папа купил лимонад и килограмм креветок – вечером будет маленькое застолье.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '38',
#   'order': '0',
#   'label': 'Fg-8F.01',
#   'lsg': '16',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '7920'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '53',
#   'order': '0',
#   'label': 'Fu-7F.02',
#   'lsg': '23',
#   'sentence': 'Дойдя до вертолётной площадки%2C мы повернулись назад и увидели закат холодное осеннего солнце.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '53',
#   'order': '0',
#   'label': 'Fu-7F.02',
#   'lsg': '23',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '6740'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '33',
#   'order': '0',
#   'label': 'Fg-5F.02',
#   'lsg': '13',
#   'sentence': 'Девчонки столпились у окна%2C чтобы посмотреть на двойную радугу%2C но никак не могли её разглядеть.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '33',
#   'order': '0',
#   'label': 'Fg-5F.02',
#   'lsg': '13',
#   'sentence': 'NULL',
#   'answer': '6',
#   'correct': 'NULL',
#   'time': '5171'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '42',
#   'order': '0',
#   'label': 'Fu-2F.01',
#   'lsg': '18',
#   'sentence': 'У меня никогда не было музыкальных способностей%2C но я отличалась склонностью рисованием. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '42',
#   'order': '0',
#   'label': 'Fu-2F.01',
#   'lsg': '18',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '6267'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '29',
#   'order': '0',
#   'label': 'Fg-3F.02',
#   'lsg': '11',
#   'sentence': 'Курины уехали на дачу на две недели%2C и до них теперь не дозвонишься.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '29',
#   'order': '0',
#   'label': 'Fg-3F.02',
#   'lsg': '11',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '7542'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '45',
#   'order': '0',
#   'label': 'Fu-3F.02',
#   'lsg': '19',
#   'sentence': 'Больше всего маленький Ваня боялся темноты%2C и поэтому света засыпал без никогда. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '45',
#   'order': '0',
#   'label': 'Fu-3F.02',
#   'lsg': '19',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '4899'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '34',
#   'order': '0',
#   'label': 'Fg-6F.01',
#   'lsg': '14',
#   'sentence': 'Никто не заставляет Витю просыпаться в шесть утра%2C он сам поднимается и идет на пробежку. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '34',
#   'order': '0',
#   'label': 'Fg-6F.01',
#   'lsg': '14',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '10345'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '49',
#   'order': '0',
#   'label': 'Fu-5F.02',
#   'lsg': '21',
#   'sentence': 'Рыбу здесь запрещено ловил сетями и пугал бы взрывчаткой.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '49',
#   'order': '0',
#   'label': 'Fu-5F.02',
#   'lsg': '21',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '2433'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '30',
#   'order': '0',
#   'label': 'Fg-4F.01',
#   'lsg': '12',
#   'sentence': 'Химия так плохо давалась Насте%2C что пришлось нанять репетитора – студента 4 курса МГУ. ',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '30',
#   'order': '0',
#   'label': 'Fg-4F.01',
#   'lsg': '12',
#   'sentence': 'NULL',
#   'answer': '7',
#   'correct': 'NULL',
#   'time': '5275'},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '54',
#   'order': '0',
#   'label': 'Fu-8F.01',
#   'lsg': '24',
#   'sentence': 'Нике явно не нравилось вечеринке%2C у неё болела голова и она поскорее хотела пойдёт домой.',
#   'answer': None,
#   'correct': None,
#   'time': None},
#  {'reception_time': '1637164987',
#   'ip': '1e377210dd0305703a3b7092c26c794c',
#   'controller': '54',
#   'order': '0',
#   'label': 'Fu-8F.01',
#   'lsg': '24',
#   'sentence': 'NULL',
#   'answer': '1',
#   'correct': 'NULL',
#   'time': '3615'},
#  ...]

# %%
norm = []
keys = ['reception_time', 'ip', 'label', 'sentence', 'answer', 'time']

for line in list(fillers)[::2]:
    dic = {}
    for key in keys:
        if line[key] and line[key] != 'NULL':
            dic[key] = line[key]
    norm.append(dic)
    
print(len(norm))
        
for line in list(fillers)[1::2]:
    for key in keys:
        if line[key] and line[key] != 'NULL':
            norm[list(fillers).index(line)//2][key] = line[key]
            
print(len(norm))
# Out:
# 1399
# 1399

# %%
with open('fillers_normal.csv', 'w') as f:
    writer = csv.DictWriter(f, fieldnames=keys)
    writer.writeheader()
    for line in norm:
        writer.writerow(line)

# %%
fig.set_axis_labels('', '')
fig.savefig('')
